# %%
# Read the SPSS Merged Median house price dataset which is available on my drive
#This data already contains no missing value and part of the preprocessing has been done in spss
import pandas as pd
df = pd.read_csv("Dataset/MergedMedianHousePrice_Deprivation_Compact1_NonMissing.csv",header=0,delimiter=',')
# Display the contents of the sheet to ensure its correct
df.head()
# Out:
#   LSOAcode2011                   LSOAname  YearendingDec1995  \
# 0    E01000001        City of London 001A           108500.0
# 1    E01000002        City of London 001B           113500.0
# 2    E01000003        City of London 001C            74000.0
# 3    E01000006  Barking and Dagenham 016A            68500.0
# 4    E01000010  Barking and Dagenham 015C            55625.0
#
#    YearendingDec1996  YearendingDec1997  YearendingDec1998  YearendingDec1999  \
# 0           150000.0           146000.0           169500.0           175500.0
# 1           122500.0           130000.0           162500.0           185000.0
# 2            76000.0           135000.0           121680.0           128000.0
# 3            69500.0            47125.0            79000.0            83500.0
# 4            52500.0            54500.0            60750.0            67000.0
#
#    YearendingDec2000  YearendingDec2001  YearendingDec2002  ...  \
# 0           245000.0           255450.0           297475.0  ...
# 1           240025.0           265000.0           285000.0  ...
# 2           145000.0           181750.0           206000.0  ...
# 3            63247.5           100000.0           137500.0  ...
# 4            87497.5            73000.0           121500.0  ...
#
#    BarrierstoHousingandServicesScore  LivingEnvironmentScore  \
# 0                             27.134                  34.502
# 1                             26.358                  37.106
# 2                             31.861                  48.337
# 3                             39.737                  30.477
# 4                             51.245                  38.231
#
#    IncomeDeprivationAffectingChildrenIndexIDACIScorerate  \
# 0                                              0.007
# 1                                              0.006
# 2                                              0.155
# 3                                              0.156
# 4                                              0.317
#
#    IncomeDeprivationAffectingOlderPeopleIDAOPIScorerate  \
# 0                                              0.019
# 1                                              0.030
# 2                                              0.160
# 3                                              0.210
# 4                                              0.494
#
#    ChildrenandYoungPeopleSubdomainScore  AdultSkillsSubdomainScore  \
# 0                                -2.194                      0.032
# 1                                -2.054                      0.034
# 2                                 0.086                      0.142
# 3                                -0.400                      0.325
# 4                                 0.159                      0.228
#
#    GeographicalBarriersSubdomainScore  WiderBarriersSubdomainScore  \
# 0                              -0.233                        2.690
# 1                              -0.208                        2.523
# 2                              -0.392                        3.726
# 3                               0.036                        4.270
# 4                              -0.772                        6.650
#
#    IndoorsSubdomainScore  OutdoorsSubdomainScore
# 0                  0.382                   1.201
# 1                  0.742                   0.806
# 2                  0.651                   1.913
# 3                  0.548                   0.590
# 4                  0.853                   0.658
#
# [5 rows x 45 columns]

# %%
#Confirm that all columns and cells are completely filled,there are no empty cells and data is in exact type
print("\nA Confirmation that all columns and cells are completely filled,there are no empty cells and data is in exact type :")
print("\nfeature_name          numbe_of_missing_values")
print(df.isnull().sum())
# Out:
# A Confirmation that all columns and cells are completely filled,there are no empty cells and data is in exact type :
#
# feature_name          numbe_of_missing_values
# LSOAcode2011                                             0
# LSOAname                                                 0
# YearendingDec1995                                        0
# YearendingDec1996                                        0
# YearendingDec1997                                        0
# YearendingDec1998                                        0
# YearendingDec1999                                        0
# YearendingDec2000                                        0
# YearendingDec2001                                        0
# YearendingDec2002                                        0
# YearendingDec2003                                        0
# YearendingDec2004                                        0
# YearendingDec2005                                        0
# YearendingDec2006                                        0
# YearendingDec2007                                        0
# YearendingDec2008                                        0
# YearendingDec2009                                        0
# YearendingDec2010                                        0
# YearendingDec2011                                        0
# YearendingDec2012                                        0
# YearendingDec2013                                        0
# YearendingDec2014                                        0
# YearendingDec2015                                        0
# YearendingDec2016                                        0
# YearendingDec2017                                        0
# YearendingDec2018                                        0
# YearendingDec2019                                        0
# YearendingDec2020                                        0
# YearendingDec2021                                        0
# IndexofMultipleDeprivationIMDScore                       0
# IncomeScorerate                                          0
# EmploymentScorerate                                      0
# EducationSkillsandTrainingScore                          0
# HealthDeprivationandDisabilityScore                      0
# CrimeScore                                               0
# BarrierstoHousingandServicesScore                        0
# LivingEnvironmentScore                                   0
# IncomeDeprivationAffectingChildrenIndexIDACIScorerate    0
# IncomeDeprivationAffectingOlderPeopleIDAOPIScorerate     0
# ChildrenandYoungPeopleSubdomainScore                     0
# AdultSkillsSubdomainScore                                0
# GeographicalBarriersSubdomainScore                       0
# WiderBarriersSubdomainScore                              0
# IndoorsSubdomainScore                                    0
# OutdoorsSubdomainScore                                   0
# dtype: int64

# %%
#check the datatypes
print("\nDisplay data types of each features")
print(df.dtypes)
# Out:
# Display data types of each features
# LSOAcode2011                                              object
# LSOAname                                                  object
# YearendingDec1995                                        float64
# YearendingDec1996                                        float64
# YearendingDec1997                                        float64
# YearendingDec1998                                        float64
# YearendingDec1999                                        float64
# YearendingDec2000                                        float64
# YearendingDec2001                                        float64
# YearendingDec2002                                        float64
# YearendingDec2003                                        float64
# YearendingDec2004                                        float64
# YearendingDec2005                                        float64
# YearendingDec2006                                        float64
# YearendingDec2007                                        float64
# YearendingDec2008                                        float64
# YearendingDec2009                                        float64
# YearendingDec2010                                        float64
# YearendingDec2011                                        float64
# YearendingDec2012                                        float64
# YearendingDec2013                                        float64
# YearendingDec2014                                        float64
# YearendingDec2015                                        float64
# YearendingDec2016                                        float64
# YearendingDec2017                                        float64
# YearendingDec2018                                        float64
# YearendingDec2019                                        float64
# YearendingDec2020                                        float64
# YearendingDec2021                                        float64
# IndexofMultipleDeprivationIMDScore                       float64
# IncomeScorerate                                          float64
# EmploymentScorerate                                      float64
# EducationSkillsandTrainingScore                          float64
# HealthDeprivationandDisabilityScore                      float64
# CrimeScore                                               float64
# BarrierstoHousingandServicesScore                        float64
# LivingEnvironmentScore                                   float64
# IncomeDeprivationAffectingChildrenIndexIDACIScorerate    float64
# IncomeDeprivationAffectingOlderPeopleIDAOPIScorerate     float64
# ChildrenandYoungPeopleSubdomainScore                     float64
# AdultSkillsSubdomainScore                                float64
# GeographicalBarriersSubdomainScore                       float64
# WiderBarriersSubdomainScore                              float64
# IndoorsSubdomainScore                                    float64
# OutdoorsSubdomainScore                                   float64
# dtype: object

# %%
#Lets start by Normalizing the data
allFeatures = [] # : all features would be stored here
allNumericFeatures = [] # : all features to ber normalized
featuresNormalized = [] # : all features wwill eventually be normalized into these designated columns
for column in df.columns:
    if df[column].dtype == 'float64':  # Check that type is float
        #Tis feature has to be normalized
            featuresNormalized.append(column+"_n")
            allNumericFeatures.append(column)

    allFeatures.append(column) #Stores all the columns or features of these dataset : wether it is old or freshly created


#I am verifying I have what into expected in my respective variables
print("\nfeatures that would be normalized ")
print(allNumericFeatures)
print("\nfeatures would be normalized into these columns : ")
print(featuresNormalized)
print("\nThese all all the features of this data set: ")
print(allFeatures)
# Out:
# features that would be normalized
# ['YearendingDec1995', 'YearendingDec1996', 'YearendingDec1997', 'YearendingDec1998', 'YearendingDec1999', 'YearendingDec2000', 'YearendingDec2001', 'YearendingDec2002', 'YearendingDec2003', 'YearendingDec2004', 'YearendingDec2005', 'YearendingDec2006', 'YearendingDec2007', 'YearendingDec2008', 'YearendingDec2009', 'YearendingDec2010', 'YearendingDec2011', 'YearendingDec2012', 'YearendingDec2013', 'YearendingDec2014', 'YearendingDec2015', 'YearendingDec2016', 'YearendingDec2017', 'YearendingDec2018', 'YearendingDec2019', 'YearendingDec2020', 'YearendingDec2021', 'IndexofMultipleDeprivationIMDScore', 'IncomeScorerate', 'EmploymentScorerate', 'EducationSkillsandTrainingScore', 'HealthDeprivationandDisabilityScore', 'CrimeScore', 'BarrierstoHousingandServicesScore', 'LivingEnvironmentScore', 'IncomeDeprivationAffectingChildrenIndexIDACIScorerate', 'IncomeDeprivationAffectingOlderPeopleIDAOPIScorerate', 'ChildrenandYoungPeopleSubdomainScore', 'AdultSkillsSubdomainScore', 'GeographicalBarriersSubdomainScore', 'WiderBarriersSubdomainScore', 'IndoorsSubdomainScore', 'OutdoorsSubdomainScore']
#
# features would be normalized into these columns :
# ['YearendingDec1995_n', 'YearendingDec1996_n', 'YearendingDec1997_n', 'YearendingDec1998_n', 'YearendingDec1999_n', 'YearendingDec2000_n', 'YearendingDec2001_n', 'YearendingDec2002_n', 'YearendingDec2003_n', 'YearendingDec2004_n', 'YearendingDec2005_n', 'YearendingDec2006_n', 'YearendingDec2007_n', 'YearendingDec2008_n', 'YearendingDec2009_n', 'YearendingDec2010_n', 'YearendingDec2011_n', 'YearendingDec2012_n', 'YearendingDec2013_n', 'YearendingDec2014_n', 'YearendingDec2015_n', 'YearendingDec2016_n', 'YearendingDec2017_n', 'YearendingDec2018_n', 'YearendingDec2019_n', 'YearendingDec2020_n', 'YearendingDec2021_n', 'IndexofMultipleDeprivationIMDScore_n', 'IncomeScorerate_n', 'EmploymentScorerate_n', 'EducationSkillsandTrainingScore_n', 'HealthDeprivationandDisabilityScore_n', 'CrimeScore_n', 'BarrierstoHousingandServicesScore_n', 'LivingEnvironmentScore_n', 'IncomeDeprivationAffectingChildrenIndexIDACIScorerate_n', 'IncomeDeprivationAffectingOlderPeopleIDAOPIScorerate_n', 'ChildrenandYoungPeopleSubdomainScore_n', 'AdultSkillsSubdomainScore_n', 'GeographicalBarriersSubdomainScore_n', 'WiderBarriersSubdomainScore_n', 'IndoorsSubdomainScore_n', 'OutdoorsSubdomainScore_n']
#
# These all all the features of this data set:
# ['LSOAcode2011', 'LSOAname', 'YearendingDec1995', 'YearendingDec1996', 'YearendingDec1997', 'YearendingDec1998', 'YearendingDec1999', 'YearendingDec2000', 'YearendingDec2001', 'YearendingDec2002', 'YearendingDec2003', 'YearendingDec2004', 'YearendingDec2005', 'YearendingDec2006', 'YearendingDec2007', 'YearendingDec2008', 'YearendingDec2009', 'YearendingDec2010', 'YearendingDec2011', 'YearendingDec2012', 'YearendingDec2013', 'YearendingDec2014', 'YearendingDec2015', 'YearendingDec2016', 'YearendingDec2017', 'YearendingDec2018', 'YearendingDec2019', 'YearendingDec2020', 'YearendingDec2021', 'IndexofMultipleDeprivationIMDScore', 'IncomeScorerate', 'EmploymentScorerate', 'EducationSkillsandTrainingScore', 'HealthDeprivationandDisabilityScore', 'CrimeScore', 'BarrierstoHousingandServicesScore', 'LivingEnvironmentScore', 'IncomeDeprivationAffectingChildrenIndexIDACIScorerate', 'IncomeDeprivationAffectingOlderPeopleIDAOPIScorerate', 'ChildrenandYoungPeopleSubdomainScore', 'AdultSkillsSubdomainScore', 'GeographicalBarriersSubdomainScore', 'WiderBarriersSubdomainScore', 'IndoorsSubdomainScore', 'OutdoorsSubdomainScore']

# %%
#Normalzie all the designated features to normalize here
#When we are normalizing we want to keep the original data untouched so we normalize into a different column
dfp = df #where dfp is dataframe processed
dfp[featuresNormalized] = dfp[allNumericFeatures].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
dfp.head()
print("finished preprocessing.....")
# Out:
#   LSOAcode2011                   LSOAname  YearendingDec1995  \
# 0    E01000001        City of London 001A           108500.0
# 1    E01000002        City of London 001B           113500.0
# 2    E01000003        City of London 001C            74000.0
# 3    E01000006  Barking and Dagenham 016A            68500.0
# 4    E01000010  Barking and Dagenham 015C            55625.0
#
#    YearendingDec1996  YearendingDec1997  YearendingDec1998  YearendingDec1999  \
# 0           150000.0           146000.0           169500.0           175500.0
# 1           122500.0           130000.0           162500.0           185000.0
# 2            76000.0           135000.0           121680.0           128000.0
# 3            69500.0            47125.0            79000.0            83500.0
# 4            52500.0            54500.0            60750.0            67000.0
#
#    YearendingDec2000  YearendingDec2001  YearendingDec2002  ...  \
# 0           245000.0           255450.0           297475.0  ...
# 1           240025.0           265000.0           285000.0  ...
# 2           145000.0           181750.0           206000.0  ...
# 3            63247.5           100000.0           137500.0  ...
# 4            87497.5            73000.0           121500.0  ...
#
#    BarrierstoHousingandServicesScore_n  LivingEnvironmentScore_n  \
# 0                             0.433882                  0.368569
# 1                             0.421269                  0.396509
# 2                             0.510711                  0.517012
# 3                             0.638722                  0.325383
# 4                             0.825765                  0.408579
#
#    IncomeDeprivationAffectingChildrenIndexIDACIScorerate_n  \
# 0                                           0.003505
# 1                                           0.002336
# 2                                           0.176402
# 3                                           0.177570
# 4                                           0.365654
#
#    IncomeDeprivationAffectingOlderPeopleIDAOPIScorerate_n  \
# 0                                           0.012333
# 1                                           0.023638
# 2                                           0.157246
# 3                                           0.208633
# 4                                           0.500514
#
#    ChildrenandYoungPeopleSubdomainScore_n  AdultSkillsSubdomainScore_n  \
# 0                                0.115658                     0.001575
# 1                                0.139934                     0.004724
# 2                                0.511011                     0.174803
# 3                                0.426738                     0.462992
# 4                                0.523669                     0.310236
#
#    GeographicalBarriersSubdomainScore_n  WiderBarriersSubdomainScore_n  \
# 0                              0.424603                       0.740624
# 1                              0.428737                       0.730098
# 2                              0.398313                       0.805925
# 3                              0.469081                       0.840214
# 4                              0.335483                       0.990230
#
#    IndoorsSubdomainScore_n  OutdoorsSubdomainScore_n
# 0                 0.593059                  0.714792
# 1                 0.649082                  0.658772
# 2                 0.634921                  0.815771
# 3                 0.618892                  0.628138
# 4                 0.666355                  0.637782
#
# [5 rows x 88 columns]
